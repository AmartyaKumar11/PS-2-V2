# %% [markdown]
# # Resume-Job Description Semantic Matching Notebook
#
# This notebook performs semantic matching between preprocessed resume data and job descriptions using Sentence-BERT. The resume data has been preprocessed and lemmatized, and now we focus on the semantic similarity matching workflow.

# %% [markdown]
# # 1. Load Preprocessed Resume Data
#
# Load the cleaned and lemmatized resume data CSV file and add unique identifiers for tracking.

# %% [markdown]
# ## 2. Load the Resume Data CSV
# Read the 'parsed_resumes.csv' file into a pandas DataFrame.

# %% [markdown]
# ## 3. Explore the Data Structure
# Display the first few rows and check column names, datatypes, and basic statistics.

# %% [markdown]
# ### Exploring Data Structure
#
# Let's examine the columns, datatypes, and basic statistics of the loaded DataFrame to understand the structure of our parsed resume data.

# %% [markdown]
# ## 4. Handle Missing Values
#
# In this section, we will identify and handle missing values in the dataset to ensure data quality for further processing.

# %% [markdown]
# ## 5. Normalize Text Columns
#
# We will now normalize text data by converting to lowercase, stripping whitespace, and standardizing formats where appropriate.

# %% [markdown]
# ## 6. Remove Duplicates
#
# Next, we will remove duplicate rows to ensure each resume entry is unique.

# %% [markdown]
# ## 7. Extract and Clean Skills
#
# We will now extract and clean the 'Skills' column, ensuring consistent formatting and removing irrelevant characters.

# %% [markdown]
# ## 8. Tokenize and Lemmatize Text Fields
#
# We will now tokenize and lemmatize relevant text fields (such as 'Summary', 'Experience', etc.) to prepare for downstream NLP tasks.

# %% [markdown]
# ## 9. Save Preprocessed Data
#
# Finally, we will save the cleaned and preprocessed DataFrame to a new CSV file for downstream analysis or modeling.

# %%
# Load the manually cleaned lemmatized CSV and add unique identifier
import pandas as pd
import numpy as np

# Load the cleaned lemmatized data
df_lemmatized = pd.read_csv('preprocessed_resumes_lemmatized.csv')

# Add unique identifier column at the start
df_lemmatized.insert(0, 'Resume_ID', range(1, len(df_lemmatized) + 1))

# Save the updated CSV with unique identifier
df_lemmatized.to_csv('preprocessed_resumes_lemmatized.csv', index=False)

print(f'Loaded {len(df_lemmatized)} resumes')
print(f'Columns: {df_lemmatized.columns.tolist()}')
print(f'Shape: {df_lemmatized.shape}')
df_lemmatized.head()
# Out:
# Lemmatized columns found: ['Education_lemmatized', 'Skills_lemmatized', 'Work Experience_lemmatized', 'Additional Information_lemmatized', 'Person Name_lemmatized', 'Certifications/Licenses_lemmatized', 'Education_lemmatized_lemmatized', 'Skills_lemmatized_lemmatized', 'Work Experience_lemmatized_lemmatized', 'Additional Information_lemmatized_lemmatized', 'Person Name_lemmatized_lemmatized', 'Certifications/Licenses_lemmatized_lemmatized', 'Education_lemmatized_lemmatized_lemmatized', 'Skills_lemmatized_lemmatized_lemmatized', 'Work Experience_lemmatized_lemmatized_lemmatized', 'Additional Information_lemmatized_lemmatized_lemmatized']
# Lemmatized data saved to preprocessed_resumes_lemmatized.csv
# Shape of lemmatized dataframe: (2437, 16)
# Columns in lemmatized CSV: ['Education_lemmatized', 'Skills_lemmatized', 'Work Experience_lemmatized', 'Additional Information_lemmatized', 'Person Name_lemmatized', 'Certifications/Licenses_lemmatized', 'Education_lemmatized_lemmatized', 'Skills_lemmatized_lemmatized', 'Work Experience_lemmatized_lemmatized', 'Additional Information_lemmatized_lemmatized', 'Person Name_lemmatized_lemmatized', 'Certifications/Licenses_lemmatized_lemmatized', 'Education_lemmatized_lemmatized_lemmatized', 'Skills_lemmatized_lemmatized_lemmatized', 'Work Experience_lemmatized_lemmatized_lemmatized', 'Additional Information_lemmatized_lemmatized_lemmatized']

# %%
# Add unique identifier (Resume_ID) to each row
# Check if Resume_ID column already exists
if 'Resume_ID' not in df_lemmatized.columns:
    # Add Resume_ID as the first column
    df_lemmatized.insert(0, 'Resume_ID', range(1, len(df_lemmatized) + 1))
    print(f'Added Resume_ID column to {len(df_lemmatized)} resumes')
else:
    print('Resume_ID column already exists')

# Display the first few rows to verify
print(f'Dataframe shape: {df_lemmatized.shape}')
print(f'Columns: {df_lemmatized.columns.tolist()}')
df_lemmatized.head()
# Out:
# Added Resume_ID column to 2437 resumes
# Dataframe shape: (2437, 18)
# Columns: ['Resume_ID', 'Education_lemmatized', 'Skills_lemmatized', 'Work Experience_lemmatized', 'Additional Information_lemmatized', 'Person Name_lemmatized', 'Certifications/Licenses_lemmatized', 'Education_lemmatized_lemmatized', 'Skills_lemmatized_lemmatized', 'Work Experience_lemmatized_lemmatized', 'Additional Information_lemmatized_lemmatized', 'Person Name_lemmatized_lemmatized', 'Certifications/Licenses_lemmatized_lemmatized', 'Education_lemmatized_lemmatized_lemmatized', 'Skills_lemmatized_lemmatized_lemmatized', 'Work Experience_lemmatized_lemmatized_lemmatized', 'Additional Information_lemmatized_lemmatized_lemmatized', 'JD_Match_Score']
#    Resume_ID                               Education_lemmatized  \
# 0          1  associate drafting technology university texas...
# 1          2  bachelor science computer criminology florida ...
# 2          3  certificate web development university wiscons...
# 3          4  certified technician telecommunication cerco i...
# 4          5  bachelor science statistic university florida ...
#
#                                    Skills_lemmatized  \
# 0  window window system administrator ii trico pr...
# 1  less average per day service desk analyst knac...
# 2  altiris apache barracuda cisco switch year web...
# 3  available resource set new computer built serv...
# 4  aws year bash year database year freebsd year ...
#
#                           Work Experience_lemmatized  \
# 0  senior system administrator trico product brow...
# 1  system administrator bios technology metairie ...
# 2  system administrator nord gear corporation wau...
# 3  roti mediterranean grill north bethesda md jan...
# 4  system administrator bex realty boca raton fl ...
#
#                    Additional Information_lemmatized Person Name_lemmatized  \
# 0
# 1                                                                         b
# 2  seasoned professional proven track record tech...                      c
# 3  technical skill patient punctual great attenti...
# 4  computer skill linux skill linux user since op...                      e
#
#                   Certifications/Licenses_lemmatized  \
# 0
# 1  comptia november november comptia november nov...
# 2
# 3                               certified technician
# 4  red hat certified system administrator august ...
#
#                      Education_lemmatized_lemmatized  \
# 0  associate drafting technology university texas...
# 1  bachelor science computer criminology florida ...
# 2  certificate web development university wiscons...
# 3  certified technician telecommunication cerco i...
# 4  bachelor science statistic university florida ...
#
#                         Skills_lemmatized_lemmatized  \
# 0  window window system administrator ii trico pr...
# 1  less average per day service desk analyst knac...
# 2  altiris apache barracuda cisco switch year web...
# 3  available resource set new computer built serv...
# 4  aws year bash year database year freebsd year ...
#
#                Work Experience_lemmatized_lemmatized  \
# 0  senior system administrator trico product brow...
# 1  system administrator bios technology metairie ...
# 2  system administrator nord gear corporation wau...
# 3  roti mediterranean grill north bethesda md jan...
# 4  system administrator bex realty boca raton fl ...
#
#         Additional Information_lemmatized_lemmatized  \
# 0
# 1
# 2  seasoned professional proven track record tech...
# 3  technical skill patient punctual great attenti...
# 4  computer skill linux skill linux user since op...
#
#   Person Name_lemmatized_lemmatized  \
# 0
# 1                                 b
# 2                                 c
# 3
# 4                                 e
#
#        Certifications/Licenses_lemmatized_lemmatized  \
# 0
# 1  comptia november november comptia november nov...
# 2
# 3                               certified technician
# 4  red hat certified system administrator august ...
#
#           Education_lemmatized_lemmatized_lemmatized  \
# 0  associate drafting technology university texas...
# 1  bachelor science computer criminology florida ...
# 2  certificate web development university wiscons...
# 3  certified technician telecommunication cerco i...
# 4  bachelor science statistic university florida ...
#
#              Skills_lemmatized_lemmatized_lemmatized  \
# 0  window window system administrator ii trico pr...
# 1  less average per day service desk analyst knac...
# 2  altiris apache barracuda cisco switch year web...
# 3  available resource set new computer built serv...
# 4  aws year bash year database year freebsd year ...
#
#     Work Experience_lemmatized_lemmatized_lemmatized  \
# 0  senior system administrator trico product brow...
# 1  system administrator bios technology metairie ...
# 2  system administrator nord gear corporation wau...
# 3  roti mediterranean grill north bethesda md jan...
# 4  system administrator bex realty boca raton fl ...
#
#   Additional Information_lemmatized_lemmatized_lemmatized  JD_Match_Score
# 0                                                                0.250928
# 1                                                                0.282353
# 2  seasoned professional proven track record tech...             0.229150
# 3  technical skill patient punctual great attenti...             0.215634
# 4  computer skill linux skill linux user since op...             0.317821

# %% [markdown]
# # 3. Resume-Job Description Semantic Matching
#
# Use Sentence-BERT to compute semantic similarity between each preprocessed resume and the job description. The similarity score indicates how well each resume matches the job requirements.

# %%
# Install required packages for semantic matching
# !pip install torch==2.2.2 --force-reinstall --no-cache-dir
# !pip install transformers==4.40.2 --force-reinstall --no-cache-dir
# !pip install sentence-transformers==2.6.1 --force-reinstall --no-cache-dir
# !pip install scikit-learn --force-reinstall --no-cache-dir
# Out:
# Collecting torch==2.2.2
#   Downloading torch-2.2.2-cp311-cp311-win_amd64.whl.metadata (26 kB)
# Collecting filelock (from torch==2.2.2)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.8.0 (from torch==2.2.2)
#   Downloading typing_extensions-4.14.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy (from torch==2.2.2)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch==2.2.2)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch==2.2.2)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch==2.2.2)
#   Downloading fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch==2.2.2)
#   Downloading MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl.metadata (4.1 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch==2.2.2)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading torch-2.2.2-cp311-cp311-win_amd64.whl (198.6 MB)
#    ---------------------------------------- 0.0/198.6 MB ? eta -:--:--
#    ---------------------------------------- 1.0/198.6 MB 6.3 MB/s eta 0:00:32
#    ---------------------------------------- 1.8/198.6 MB 4.8 MB/s eta 0:00:42
#     --------------------------------------- 2.6/198.6 MB 4.4 MB/s eta 0:00:45
#     --------------------------------------- 3.4/198.6 MB 4.3 MB/s eta 0:00:46
#     --------------------------------------- 4.5/198.6 MB 4.1 MB/s eta 0:00:48
#    - -------------------------------------- 5.2/198.6 MB 4.1 MB/s eta 0:00:48
#    - -------------------------------------- 6.0/198.6 MB 4.1 MB/s eta 0:00:48
#    - -------------------------------------- 6.8/198.6 MB 4.1 MB/s eta 0:00:48
#    - -------------------------------------- 7.6/198.6 MB 4.0 MB/s eta 0:00:48
#    - -------------------------------------- 8.4/198.6 MB 4.0 MB/s eta 0:00:48
#    - -------------------------------------- 9.4/198.6 MB 4.0 MB/s eta 0:00:48
#    -- ------------------------------------- 10.2/198.6 MB 4.0 MB/s eta 0:00:48
#    -- ------------------------------------- 10.7/198.6 MB 4.0 MB/s eta 0:00:48
#    -- ------------------------------------- 11.8/198.6 MB 4.0 MB/s eta 0:00:48
#    -- ------------------------------------- 12.6/198.6 MB 4.0 MB/s eta 0:00:47
#    -- ------------------------------------- 13.4/198.6 MB 4.0 MB/s eta 0:00:47
#    -- ------------------------------------- 14.2/198.6 MB 4.0 MB/s eta 0:00:47
#    --- ------------------------------------ 14.9/198.6 MB 3.9 MB/s eta 0:00:47
#    --- ------------------------------------ 15.7/198.6 MB 3.9 MB/s eta 0:00:47
#    --- ------------------------------------ 16.8/198.6 MB 3.9 MB/s eta 0:00:47
#    --- ------------------------------------ 17.6/198.6 MB 3.9 MB/s eta 0:00:47
#    --- ------------------------------------ 18.4/198.6 MB 3.9 MB/s eta 0:00:46
#    --- ------------------------------------ 19.1/198.6 MB 3.9 MB/s eta 0:00:46
#    ---- ----------------------------------- 19.9/198.6 MB 3.9 MB/s eta 0:00:46
#    ---- ----------------------------------- 20.7/198.6 MB 3.9 MB/s eta 0:00:46
#    ---- ----------------------------------- 21.8/198.6 MB 3.9 MB/s eta 0:00:46
#    ---- ----------------------------------- 22.5/198.6 MB 3.9 MB/s eta 0:00:45
#    ---- ----------------------------------- 23.3/198.6 MB 3.9 MB/s eta 0:00:45
#    ---- ----------------------------------- 24.1/198.6 MB 3.9 MB/s eta 0:00:45
#    ----- ---------------------------------- 24.9/198.6 MB 3.9 MB/s eta 0:00:45
#    ----- ---------------------------------- 25.7/198.6 MB 3.9 MB/s eta 0:00:45
#    ----- ---------------------------------- 26.2/198.6 MB 3.9 MB/s eta 0:00:45
#    ----- ----------------------------------
#    -------------------------------- ------- 160.7/198.6 MB 3.7 MB/s eta 0:00:11
#    -------------------------------- ------- 161.5/198.6 MB 3.7 MB/s eta 0:00:11
#    -------------------------------- ------- 162.3/198.6 MB 3.7 MB/s eta 0:00:10
#    -------------------------------- ------- 163.1/198.6 MB 3.7 MB/s eta 0:00:10
#    --------------------------------- ------ 163.8/198.6 MB 3.7 MB/s eta 0:00:10
#    --------------------------------- ------ 164.9/198.6 MB 3.7 MB/s eta 0:00:10
#    --------------------------------- ------ 165.7/198.6 MB 3.7 MB/s eta 0:00:09
#    --------------------------------- ------ 166.5/198.6 MB 3.7 MB/s eta 0:00:09
#    --------------------------------- ------ 167.2/198.6 MB 3.7 MB/s eta 0:00:09
#    --------------------------------- ------ 168.0/198.6 MB 3.7 MB/s eta 0:00:09
#    ---------------------------------- ----- 168.8/198.6 MB 3.7 MB/s eta 0:00:09
#    ---------------------------------- ----- 169.6/198.6 MB 3.7 MB/s eta 0:00:08
#    ---------------------------------- ----- 170.4/198.6 MB 3.7 MB/s eta 0:00:08
#    ---------------------------------- ----- 171.2/198.6 MB 3.7 MB/s eta 0:00:08
#    ---------------------------------- ----- 172.0/198.6 MB 3.7 MB/s eta 0:00:08
#    ---------------------------------- ----- 172.8/198.6 MB 3.7 MB/s eta 0:00:07
#    ---------------------------------- ----- 173.5/198.6 MB 3.7 MB/s eta 0:00:07
#    ----------------------------------- ---- 174.3/198.6 MB 3.7 MB/s eta 0:00:07
#    ----------------------------------- ---- 175.4/198.6 MB 3.7 MB/s eta 0:00:07
#    ----------------------------------- ---- 176.2/198.6 MB 3.7 MB/s eta 0:00:07
#    ----------------------------------- ---- 176.9/198.6 MB 3.7 MB/s eta 0:00:06
#    ----------------------------------- ---- 177.7/198.6 MB 3.7 MB/s eta 0:00:06
#    ----------------------------------- ---- 178.5/198.6 MB 3.7 MB/s eta 0:00:06
#    ------------------------------------ --- 179.3/198.6 MB 3.7 MB/s eta 0:00:06
#    ------------------------------------ --- 180.1/198.6 MB 3.7 MB/s eta 0:00:05
#    ------------------------------------ --- 181.1/198.6 MB 3.9 MB/s eta 0:00:05
#    ------------------------------------ --- 181.9/198.6 MB 3.9 MB/s eta 0:00:05
#    ------------------------------------ --- 182.7/198.6 MB 3.9 MB/s eta 0:00:05
#    ------------------------------------ --- 183.5/198.6 MB 3.9 MB/s eta 0:00:04
#    ------------------------------------- -- 184.3/198.6 MB 3.8 MB/s eta 0:00:04
#    ------------------------------------- -- 185.1/198.6 MB 3.8 MB/s eta 0:00:04
#    ------------------------------------- -- 185.9/198.6 MB 3.8 MB/s eta 0:00:04
#    ------------------------------------- -- 186.6/198.6 MB 3.8 MB/s eta 0:00:04
#    ------------------------------------- -- 187.4/198.6 MB 3.8 MB/s eta 0:00:03
#    ------------------------------------- -- 188.2/198.6 MB 3.9 MB/s eta 0:00:03
#    -------------------------------------- - 189.0/198.6 MB 3.8 MB/s eta 0:00:03
#    -------------------------------------- - 189.8/198.6 MB 3.9 MB/s eta 0:00:03
#    -------------------------------------- - 190.8/198.6 MB 3.9 MB/s eta 0:00:03
#    -------------------------------------- - 191.6/198.6 MB 3.9 MB/s eta 0:00:02
#    -------------------------------------- - 192.4/198.6 MB 3.9 MB/s eta 0:00:02
#    -------------------------------------- - 193.2/198.6 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------------  194.0/198.6 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------------  194.8/198.6 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  195.6/198.6 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  196.3/198.6 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  197.4/198.6 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  198.2/198.6 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 198.6/198.6 MB 3.9 MB/s eta 0:00:00
# Downloading typing_extensions-4.14.0-py3-none-any.whl (43 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.5.1-py3-none-any.whl (199 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl (15 kB)
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.0 MB 3.7 MB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.0 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 3.9 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/6.3 MB 3.7 MB/s eta 0:00:02
#    --------- ------------------------------ 1.6/6.3 MB 3.8 MB/s eta 0:00:02
#    -------------- ------------------------- 2.4/6.3 MB 3.8 MB/s eta 0:00:02
#    ------------------- -------------------- 3.1/6.3 MB 3.9 MB/s eta 0:00:01
#    ------------------------ --------------- 3.9/6.3 MB 3.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.7/6.3 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.5/6.3 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 3.9 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: mpmath, typing-extensions, sympy, networkx, MarkupSafe, fsspec, filelock, jinja2, torch
#
#   Attempting uninstall: mpmath
#
#     Found existing installation: mpmath 1.3.0
#
#     Uninstalling mpmath-1.3.0:
#
#       Successfully uninstalled mpmath-1.3.0
#
#    ---------------------------------------- 0/9 [mpmath]
#    ---------------------------------------- 0/9 [mpmath]
#    ---------------------------------------- 0/9 [mpmath]
#   Attempting uninstall: typing-extensions
#    ---------------------------------------- 0/9 [mpmath]
#     Found existing installation: typing_extensions 4.14.0
#    ---------------------------------------- 0/9 [mpmath]
#     Uninstalling typing_extensions-4.14.0:
#    ---------------------------------------- 0/9 [mpmath]
#    ---- ----------------------------------- 1/9 [typing-extensions]
#    ---- ----------------------------------- 1/9 [typing-extensions]
#    ---- ----------------------------------- 1/9 [typing-extensions]
#    ---- ----------------------------------- 1/9 [typing-extensions]
#    ---- ----------------------------------- 1/9 [typing-extensions]
#    ---- ----------------------------------- 1/9 [typing-extensions]
#    ---- ----------------------------------- 1/9 [typing-extensions]
#    ---- ----------------------------------- 1/9 [typing-extensions]
#    ---- ----------------------------------- 1/9 [typing-extensions]
#    ---- ----------------------------------- 1/9 [typing-extensions]
#    ---- ----------------------------------- 1/9 [typing-extensions]
#    ---- ----------------------------------- 1/9 [typing-extensions]
#    ---- ----------------------------------- 1/9 [typing-extensions]
#    ---- ----------------------------------- 1/9 [typing-extensions]
#    ---- ----------------------------------- 1/9 [typing-extensions]
#    ---- ----------------------------------- 1/9 [typing-extensions]
#       Successfully uninstalled typing_extensions-4.14.0
#    ---- ----------------------------------- 1/9 [typing-extensions]
#   Attempting uninstall: sympy
#    ---- ----------------------------------- 1/9 [typing-extensions]
#     Found existing installation: sympy 1.14.0
#    ---- ----------------------------------- 1/9 [typing-extensions]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#     Uninstalling sympy-1.14.0:
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#       Successfully uninstalled sympy-1.14.0
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#   Attempting uninstall: networkx
#    -------- ------------------------------- 2/9 [sympy]
#     Found existing installation: networkx 3.5
#    -------- ------------------------------- 2/9 [sympy]
#    ------------- -------------------------- 3/9 [networkx]
#     Uninstalling networkx-3.5:
#    ------------- -------------------------- 3/9 [networkx]
#    ------------- -------------------------- 3/9 [networkx]
#       Successfully uninstalled networkx-3.5
#    ------------- -------------------------- 3/9 [networkx]
#    ------------- -------------------------- 3/9 [networkx]
#    ------------- -------------------------- 3/9 [networkx]
#    ------------- -------------------------- 3/9 [networkx]
#    ------------- -------------------------- 3/9 [networkx]
#    ------------- -------------------------- 3/9 [networkx]
#    ------------- -------------------------- 3/9 [networkx]
#    ------------- -------------------------- 3/9 [networkx]
#    ------------- -------------------------- 3/9 [networkx]
#    ------------- -------------------------- 3/9 [networkx]
#    ------------- -------------------------- 3/9 [networkx]
#    ------------- -------------------------- 3/9 [networkx]
#    ------------- -------------------------- 3/9 [networkx]
#    ------------- -------------------------- 3/9 [networkx]
#    ------------- -------------------------- 3/9 [networkx]
#    ------------- -------------------------- 3/9 [networkx]
#    ------------- -------------------------- 3/9 [networkx]
#   Attempting uninstall: MarkupSafe
#    ------------- -------------------------- 3/9 [networkx]
#     Found existing installation: MarkupSafe 3.0.2
#    ------------- -------------------------- 3/9 [networkx]
#     Uninstalling MarkupSafe-3.0.2:
#    ------------- -------------------------- 3/9 [networkx]
#       Successfully uninstalled MarkupSafe-3.0.2
#    ------------- -------------------------- 3/9 [networkx]
#   Attempting uninstall: fsspec
#    ------------- -------------------------- 3/9 [networkx]
#     Found existing installation: fsspec 2025.5.1
#    ------------- -------------------------- 3/9 [networkx]
#     Uninstalling fsspec-2025.5.1:
#    ------------- -------------------------- 3/9 [networkx]
#       Successfully uninstalled fsspec-2025.5.1
#    ------------- -------------------------- 3/9 [networkx]
#    ---------------------- ----------------- 5/9 [fsspec]
#    ---------------------- ----------------- 5/9 [fsspec]
#   Attempting uninstall: filelock
#    ---------------------- ----------------- 5/9 [fsspec]
#     Found existing installation: filelock 3.18.0
#    ---------------------- ----------------- 5/9 [fsspec]
#     Uninstalling filelock-3.18.0:
#    ---------------------- ----------------- 5/9 [fsspec]
#       Successfully uninstalled filelock-3.18.0
#    ---------------------- ----------------- 5/9 [fsspec]
#   Attempting uninstall: jinja2
#    ---------------------- ----------------- 5/9 [fsspec]
#     Found existing installation: Jinja2 3.1.6
#    ---------------------- ----------------- 5/9 [fsspec]
#     Uninstalling Jinja2-3.1.6:
#    ---------------------- ----------------- 5/9 [fsspec]
#       Successfully uninstalled Jinja2-3.1.6
#    ---------------------- ----------------- 5/9 [fsspec]
#    ------------------------------- -------- 7/9 [jinja2]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ----------------------------------- ---- 8/9 [torch]
#    ---------------------------------------- 9/9 [torch]
#
# Successfully installed MarkupSafe-3.0.2 filelock-3.18.0 fsspec-2025.5.1 jinja2-3.1.6 mpmath-1.3.0 networkx-3.5 sympy-1.14.0 torch-2.2.2 typing-extensions-4.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.16.1 requires keras>=3.0.0, which is not installed.
# s3fs 2023.10.0 requires fsspec==2023.10.0, but you have fsspec 2025.5.1 which is incompatible.
# streamlit 1.30.0 requires numpy<2,>=1.19.3, but you have numpy 2.3.1 which is incompatible.
# streamlit 1.30.0 requires packaging<24,>=16.8, but you have packaging 25.0 which is incompatible.
# streamlit 1.30.0 requires pillow<11,>=7.1.0, but you have pillow 11.3.0 which is incompatible.
# streamlit 1.30.0 requires protobuf<5,>=3.20, but you have protobuf 5.29.5 which is incompatible.
# streamlit 1.30.0 requires rich<14,>=10.14.0, but you have rich 14.0.0 which is incompatible.
# tensorflow-intel 2.16.1 requires ml-dtypes~=0.3.1, but you have ml-dtypes 0.5.1 which is incompatible.
# tensorflow-intel 2.16.1 requires numpy<2.0.0,>=1.23.5; python_version <= "3.11", but you have numpy 2.3.1 which is incompatible.
# tensorflow-intel 2.16.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.5 which is incompatible.
# tensorflow-intel 2.16.1 requires tensorboard<2.17,>=2.16, but you have tensorboard 2.19.0 which is incompatible.
# Collecting transformers==4.40.2
#   Downloading transformers-4.40.2-py3-none-any.whl.metadata (137 kB)
# Collecting filelock (from transformers==4.40.2)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting huggingface-hub<1.0,>=0.19.3 (from transformers==4.40.2)
#   Downloading huggingface_hub-0.33.2-py3-none-any.whl.metadata (14 kB)
# Collecting numpy>=1.17 (from transformers==4.40.2)
#   Downloading numpy-2.3.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting packaging>=20.0 (from transformers==4.40.2)
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pyyaml>=5.1 (from transformers==4.40.2)
#   Downloading PyYAML-6.0.2-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Collecting regex!=2019.12.17 (from transformers==4.40.2)
#   Downloading regex-2024.11.6-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Collecting requests (from transformers==4.40.2)
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting tokenizers<0.20,>=0.19 (from transformers==4.40.2)
#   Downloading tokenizers-0.19.1-cp311-none-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.1 (from transformers==4.40.2)
#   Downloading safetensors-0.5.3-cp38-abi3-win_amd64.whl.metadata (3.9 kB)
# Collecting tqdm>=4.27 (from transformers==4.40.2)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.19.3->transformers==4.40.2)
#   Downloading fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# Collecting typing-extensions>=3.7.4.3 (from huggingface-hub<1.0,>=0.19.3->transformers==4.40.2)
#   Downloading typing_extensions-4.14.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting colorama (from tqdm>=4.27->transformers==4.40.2)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting charset_normalizer<4,>=2 (from requests->transformers==4.40.2)
#   Downloading charset_normalizer-3.4.2-cp311-cp311-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests->transformers==4.40.2)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->transformers==4.40.2)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->transformers==4.40.2)
#   Downloading certifi-2025.6.15-py3-none-any.whl.metadata (2.4 kB)
# Downloading transformers-4.40.2-py3-none-any.whl (9.0 MB)
#    ---------------------------------------- 0.0/9.0 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.0 MB 5.6 MB/s eta 0:00:02
#    -------- ------------------------------- 1.8/9.0 MB 4.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.6/9.0 MB 4.3 MB/s eta 0:00:02
#    --------------- ------------------------ 3.4/9.0 MB 4.2 MB/s eta 0:00:02
#    ------------------- -------------------- 4.5/9.0 MB 4.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.2/9.0 MB 4.0 MB/s eta 0:00:01
#    -------------------------- ------------- 6.0/9.0 MB 4.0 MB/s eta 0:00:01
#    ------------------------------ --------- 6.8/9.0 MB 4.0 MB/s eta 0:00:01
#    --------------------------------- ------ 7.6/9.0 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------- -- 8.4/9.0 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.0/9.0 MB 4.0 MB/s eta 0:00:00
# Downloading huggingface_hub-0.33.2-py3-none-any.whl (515 kB)
# Downloading tokenizers-0.19.1-cp311-none-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.2 MB 3.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.6/2.2 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 3.9 MB/s eta 0:00:00
# Downloading fsspec-2025.5.1-py3-none-any.whl (199 kB)
# Downloading numpy-2.3.1-cp311-cp311-win_amd64.whl (13.0 MB)
#    ---------------------------------------- 0.0/13.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/13.0 MB 3.7 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.6/13.0 MB 3.8 MB/s eta 0:00:04
#    ------- -------------------------------- 2.4/13.0 MB 3.8 MB/s eta 0:00:03
#    --------- ------------------------------ 3.1/13.0 MB 3.8 MB/s eta 0:00:03
#    ------------ --------------------------- 3.9/13.0 MB 3.8 MB/s eta 0:00:03
#    -------------- ------------------------- 4.7/13.0 MB 3.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.8/13.0 MB 3.8 MB/s eta 0:00:02
#    -------------------- ------------------- 6.6/13.0 MB 3.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.3/13.0 MB 3.9 MB/s eta 0:00:02
#    ------------------------ --------------- 8.1/13.0 MB 3.9 MB/s eta 0:00:02
#    --------------------------- ------------ 8.9/13.0 MB 3.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.7/13.0 MB 3.8 MB/s eta 0:00:01
#    -------------------------------- ------- 10.5/13.0 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.3/13.0 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 12.3/13.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 13.0/13.0 MB 3.9 MB/s eta 0:00:00
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
# Downloading PyYAML-6.0.2-cp311-cp311-win_amd64.whl (161 kB)
# Downloading regex-2024.11.6-cp311-cp311-win_amd64.whl (274 kB)
# Downloading safetensors-0.5.3-cp38-abi3-win_amd64.whl (308 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typing_extensions-4.14.0-py3-none-any.whl (43 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp311-cp311-win_amd64.whl (105 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.6.15-py3-none-any.whl (157 kB)
# Installing collected packages: urllib3, typing-extensions, safetensors, regex, pyyaml, packaging, numpy, idna, fsspec, filelock, colorama, charset_normalizer, certifi, tqdm, requests, huggingface-hub, tokenizers, transformers
#
#   Attempting uninstall: urllib3
#
#     Found existing installation: urllib3 2.5.0
#
#     Uninstalling urllib3-2.5.0:
#
#       Successfully uninstalled urllib3-2.5.0
#
#    ----------------------------------------  0/18 [urllib3]
#   Attempting uninstall: typing-extensions
#    ----------------------------------------  0/18 [urllib3]
#     Found existing installation: typing_extensions 4.14.0
#    ----------------------------------------  0/18 [urllib3]
#     Uninstalling typing_extensions-4.14.0:
#    ----------------------------------------  0/18 [urllib3]
#    -- -------------------------------------  1/18 [typing-extensions]
#    -- -------------------------------------  1/18 [typing-extensions]
#    -- -------------------------------------  1/18 [typing-extensions]
#    -- -------------------------------------  1/18 [typing-extensions]
#    -- -------------------------------------  1/18 [typing-extensions]
#    -- -------------------------------------  1/18 [typing-extensions]
#    -- -------------------------------------  1/18 [typing-extensions]
#    -- -------------------------------------  1/18 [typing-extensions]
#    -- -------------------------------------  1/18 [typing-extensions]
#    -- -------------------------------------  1/18 [typing-extensions]
#    -- -------------------------------------  1/18 [typing-extensions]
#       Successfully uninstalled typing_extensions-4.14.0
#    -- -------------------------------------  1/18 [typing-extensions]
#   Attempting uninstall: safetensors
#    -- -------------------------------------  1/18 [typing-extensions]
#     Found existing installation: safetensors 0.5.3
#    -- -------------------------------------  1/18 [typing-extensions]
#     Uninstalling safetensors-0.5.3:
#    -- -------------------------------------  1/18 [typing-extensions]
#       Successfully uninstalled safetensors-0.5.3
#    -- -------------------------------------  1/18 [typing-extensions]
#   Attempting uninstall: regex
#    -- -------------------------------------  1/18 [typing-extensions]
#     Found existing installation: regex 2024.11.6
#    -- -------------------------------------  1/18 [typing-extensions]
#    ------ ---------------------------------  3/18 [regex]
#     Uninstalling regex-2024.11.6:
#    ------ ---------------------------------  3/18 [regex]
#       Successfully uninstalled regex-2024.11.6
#    ------ ---------------------------------  3/18 [regex]
#    ------ ---------------------------------  3/18 [regex]
#    ------ ---------------------------------  3/18 [regex]
#    ------ ---------------------------------  3/18 [regex]
#    ------ ---------------------------------  3/18 [regex]
#    ------ ---------------------------------  3/18 [regex]
#    ------ ---------------------------------  3/18 [regex]
#    ------ ---------------------------------  3/18 [regex]
#    ------ ---------------------------------  3/18 [regex]
#    ------ ---------------------------------  3/18 [regex]
#    ------ ---------------------------------  3/18 [regex]
#    ------ ---------------------------------  3/18 [regex]
#    ------ ---------------------------------  3/18 [regex]
#    ------ ---------------------------------  3/18 [regex]
#    ------ ---------------------------------  3/18 [regex]
#    ------ ---------------------------------  3/18 [regex]
#    ------ ---------------------------------  3/18 [regex]
#    ------ ---------------------------------  3/18 [regex]
9 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.3/38.6 MB 3.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.1/38.6 MB 3.9 MB/s eta 0:00:02
#    ------------------------------------ --- 34.9/38.6 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 35.7/38.6 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 36.4/38.6 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 37.2/38.6 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.6 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 38.6/38.6 MB 3.9 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, numpy, joblib, scipy, scikit-learn
#
#   Attempting uninstall: threadpoolctl
#
#     Found existing installation: threadpoolctl 3.6.0
#
#     Uninstalling threadpoolctl-3.6.0:
#
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#    ---------------------------------------- 0/5 [threadpoolctl]
#       Successfully uninstalled threadpoolctl-3.6.0
#    ---------------------------------------- 0/5 [threadpoolctl]
#   Attempting uninstall: numpy
#    ---------------------------------------- 0/5 [threadpoolctl]
#     Found existing installation: numpy 2.3.1
#    ---------------------------------------- 0/5 [threadpoolctl]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#     Uninstalling numpy-2.3.1:
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#       Successfully uninstalled numpy-2.3.1
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#   Attempting uninstall: joblib
#    -------- ------------------------------- 1/5 [numpy]
#     Found existing installation: joblib 1.5.1
#    -------- ------------------------------- 1/5 [numpy]
#     Uninstalling joblib-1.5.1:
#    -------- ------------------------------- 1/5 [numpy]
#       Successfully uninstalled joblib-1.5.1
#    -------- ------------------------------- 1/5 [numpy]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#   Attempting uninstall: scipy
#    ---------------- ----------------------- 2/5 [joblib]
#     Found existing installation: scipy 1.16.0
#    ---------------- ----------------------- 2/5 [joblib]
#    ------------------------ --------------- 3/5 [scipy]
#     Uninstalling scipy-1.16.0:
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#       Successfully uninstalled scipy-1.16.0
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#   Attempting uninstall: scikit-learn
#    ------------------------ --------------- 3/5 [scipy]
#     Found existing installation: scikit-learn 1.7.0
#    ------------------------ --------------- 3/5 [scipy]
#    -------------------------------- ------- 4/5 [scikit-learn]
#     Uninstalling scikit-learn-1.7.0:
#    -------------------------------- ------- 4/5 [scikit-learn]
#       Successfully uninstalled scikit-learn-1.7.0
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    ---------------------------------------- 5/5 [scikit-learn]
#
# Successfully installed joblib-1.5.1 numpy-2.3.1 scikit-learn-1.7.0 scipy-1.16.0 threadpoolctl-3.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# tensorflow-intel 2.16.1 requires keras>=3.0.0, which is not installed.
# astropy 5.3.4 requires numpy<2,>=1.21, but you have numpy 2.3.1 which is incompatible.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.3.1 which is incompatible.
# numba 0.59.0 requires numpy<1.27,>=1.22, but you have numpy 2.3.1 which is incompatible.
# pywavelets 1.5.0 requires numpy<2.0,>=1.22.4, but you have numpy 2.3.1 which is incompatible.
# streamlit 1.30.0 requires numpy<2,>=1.19.3, but you have numpy 2.3.1 which is incompatible.
# streamlit 1.30.0 requires packaging<24,>=16.8, but you have packaging 25.0 which is incompatible.
# streamlit 1.30.0 requires pillow<11,>=7.1.0, but you have pillow 11.3.0 which is incompatible.
# streamlit 1.30.0 requires protobuf<5,>=3.20, but you have protobuf 5.29.5 which is incompatible.
# streamlit 1.30.0 requires rich<14,>=10.14.0, but you have rich 14.0.0 which is incompatible.
# tensorflow-intel 2.16.1 requires ml-dtypes~=0.3.1, but you have ml-dtypes 0.5.1 which is incompatible.
# tensorflow-intel 2.16.1 requires numpy<2.0.0,>=1.23.5; python_version <= "3.11", but you have numpy 2.3.1 which is incompatible.
# tensorflow-intel 2.16.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.5 which is incompatible.
# tensorflow-intel 2.16.1 requires tensorboard<2.17,>=2.16, but you have tensorboard 2.19.0 which is incompatible.

# %% [markdown]
# # 2. Install Dependencies
#
# Install the required packages for semantic matching with Sentence-BERT.

# %%
# Load the job description from file
with open(r'c:/Users/AMARTYA KUMAR/Desktop/PS-2/PS-2 functions/Web-Developer-job-description.txt', 'r', encoding='utf-8') as f:
    job_description = f.read()
print(job_description)
# Out:
# Job Title: Web Developer
# Company: Not specified
# Department: engineering
# Level: intern
# Work Mode: remote
# Location: Not specified
# Salary: EUR1K - EUR2K
# Job Type: internship
# Description: We need web developers with expertise in at least 1 of the following skills - Node.js, Nest.js, Vue.js, Laravel.
#
# Selected Intern's day-to-day responsibilities include creating websites through Node.js, Nest.js, Vue.js, etc.
#
# Please do not apply if you do not have expertise.
#
# We are looking only for serious interns. To prevent mutual waste of time, energy, and resources, any intern not working seriously can be removed with immediate effect without any benefits being given. We will give intern certificates, etc., to only those who have contributed sufficiently.

# %%
# Semantic matching using Sentence-BERT
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Load the model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Prepare resume texts (concatenate all lemmatized fields)
resume_texts = df_lemmatized.apply(lambda row: ' '.join([
    str(row.get('Person Name_lemmatized', '')),
    str(row.get('Work Experience_lemmatized', '')),
    str(row.get('Skills_lemmatized', '')),
    str(row.get('Education_lemmatized', '')),
    str(row.get('Certifications/Licenses_lemmatized', '')),
    str(row.get('Additional Information_lemmatized', ''))
]), axis=1).tolist()

print(f'Processing {len(resume_texts)} resumes for semantic matching...')

# Encode resumes and job description
resume_embeddings = model.encode(resume_texts, convert_to_numpy=True)
jd_embedding = model.encode([job_description], convert_to_numpy=True)

# Compute cosine similarity
similarity_scores = cosine_similarity(resume_embeddings, jd_embedding).flatten()

# Add match scores to dataframe
df_lemmatized['JD_Match_Score'] = similarity_scores

# Show top 10 matches
top_matches = df_lemmatized.sort_values('JD_Match_Score', ascending=False).head(10)
print('\nTop 10 Resume Matches:')
display(top_matches[['Resume_ID', 'Person Name_lemmatized', 'Skills_lemmatized', 'JD_Match_Score']])

# Save results
df_lemmatized.to_csv('resume_matching_results_final.csv', index=False)
print(f'\nResults saved to resume_matching_results_final.csv')
# Out:
# Processing 2437 resumes for semantic matching...
#
# Top 10 Resume Matches:
#
# Top 10 Resume Matches:
#       Resume_ID Person Name_lemmatized  \
# 637         638                     xn
# 693         694                     zr
# 858         859                    aga
# 748         749                    abu
# 715         716                    aan
# 656         657                     yg
# 608         609                     wk
# 643         644                     xt
# 803         804                    adx
# 1913       1914                    bup
#
#                                       Skills_lemmatized  JD_Match_Score
# 637   year bootstrap expressjs year ajax year year a...        0.625818
# 693   year bootstrap expressjs year ajax year year a...        0.616476
# 858   year bootstrap expressjs year ajax year year a...        0.603025
# 748   front end less year javascript less year ui le...        0.583438
# 715                         coding year troubleshooting        0.554881
# 656                         coding year troubleshooting        0.544948
# 608                              avocode year photoshop        0.529047
# 643   cooporate design team create simple beautiful ...        0.508679
# 803   angular less year front end less year javascri...        0.483990
# 1913  ajax bootstrap cs dhtml html javascript jquery...        0.481086
# Results saved to resume_matching_results_final.csv
